# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Ibscai42.DGVC-MCA\25E5842\Students.csv")
print(df)
# Out:
#    Roll no     Name Departments  Marks
# 0      101      Anu         CSE     55
# 1      102     Sree          AF     90
# 2      103  Preethi       Maths     89
# 3      104   Paulin     Physics     99
# 4      105    Gopzz         MCA     78
