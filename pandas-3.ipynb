# %%
import pandas as pd
data={
    'roll no':[101,102,103,104,105,106,107,108,109,110],
    'name':['arun','priya','rahul','anu','ani','annish','anbu','swathi','sree','gopzz'],
    'marks':[85,90,78,43,65,22,65,78,76,97]
    }
df=pd.DataFrame(data)
print(df)
# Out:
#    roll no    name  marks
# 0      101    arun     85
# 1      102   priya     90
# 2      103   rahul     78
# 3      104     anu     43
# 4      105     ani     65
# 5      106  annish     22
# 6      107    anbu     65
# 7      108  swathi     78
# 8      109    sree     76
# 9      110   gopzz     97

# %%
print(df.sort_values('marks',ascending=True))
# Out:
#    roll no    name  marks
# 5      106  annish     22
# 3      104     anu     43
# 4      105     ani     65
# 6      107    anbu     65
# 8      109    sree     76
# 2      103   rahul     78
# 7      108  swathi     78
# 0      101    arun     85
# 1      102   priya     90
# 9      110   gopzz     97

# %%
print(df.sort_values('marks',ascending=False))
# Out:
#    roll no    name  marks
# 9      110   gopzz     97
# 1      102   priya     90
# 0      101    arun     85
# 2      103   rahul     78
# 7      108  swathi     78
# 8      109    sree     76
# 4      105     ani     65
# 6      107    anbu     65
# 3      104     anu     43
# 5      106  annish     22

# %%
import pandas as pd
data={
    'roll no':[11,12,13,14,15,16,17,18,19,10],
    'name':['arun','priya','rahul','anu','ani','annish','anbu','swathi','sree','gopzz'],
    'dept':['cs','ds','af','ad','sa','finance','ds','hr','kl','fn']
   
    }
df=pd.DataFrame(data)

# %%
print(df)
# Out:
#    roll no    name     dept
# 0       11    arun       cs
# 1       12   priya       ds
# 2       13   rahul       af
# 3       14     anu       ad
# 4       15     ani       sa
# 5       16  annish  finance
# 6       17    anbu       ds
# 7       18  swathi       hr
# 8       19    sree       kl
# 9       10   gopzz       fn
