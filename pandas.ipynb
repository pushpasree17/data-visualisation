# %%
import pandas as pd
s=pd.Series([10,20,30,40])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
s=pd.Series([100,200,300,400])
print(s)
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# dtype: int64

# %%
s=pd.Series([100,200,300,400],
index=['A','B','C','D'])
print(s)
# Out:
# A    100
# B    200
# C    300
# D    400
# dtype: int64

# %%
Data={'maths':90,'physics':78,'chemistry':98,'cs':99}
s=pd.Series(Data)
print(s)
# Out:
# maths        90
# physics      78
# chemistry    98
# cs           99
# dtype: int64

# %%
s=pd.Series([10,20,30,40])
print(s[0])
# Out:
# 10

# %%
s=pd.Series([100,200,300],index=['A','B','C'])
print(s['C'])
# Out:
# 300

# %%
print(s[['A','C']])
# Out:
# A    100
# C    300
# dtype: int64

# %%
print(s.size)
# Out:
# 3

# %%
print(s.shape)
# Out:
# (3,)

# %%
s=pd.Series([10,20,30,40])
print(s+10)
# Out:
# 0    20
# 1    30
# 2    40
# 3    50
# dtype: int64

# %%
print("Sum=",s.sum())
print("mean=",s.mean())
print("maximum=",s.max())
print("minimum=",s.min())
# Out:
# Sum= 100
# mean= 25.0
# maximum= 40
# minimum= 10

# %%
data={
    'roll no':[101,102,103],
    'name':['arun','priya','rahul'],
    'marks':[85,90,78]
    }
df=pd.DataFrame(data)
print(df)
# Out:
#    roll no   name  marks
# 0      101   arun     85
# 1      102  priya     90
# 2      103  rahul     78

# %%
df=pd.DataFrame(data,
                index=['A','B','C'])
print(df)
# Out:
#    roll no   name  marks
# A      101   arun     85
# B      102  priya     90
# C      103  rahul     78

# %%
print(df.columns)
# Out:
# Index(['roll no', 'name', 'marks'], dtype='object')
